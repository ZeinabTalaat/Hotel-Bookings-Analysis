# %% [markdown]
# # المكتبات

# %%
import pandas as pd
import numpy as np
import nbformat as nbf
from datetime import datetime
from pathlib import Path
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # DATA PATH

# %%
input_path = r"c:\Users\SPEED LAP\OneDrive\Desktop\hotel_bookings FP MSA.csv"

# %% [markdown]
# # OUTPUT PATH

# %%
desktop_folder = Path(input_path).parent  
clean_csv_path = desktop_folder / "hotel_bookings_Cleaned.csv"

# %% [markdown]
# # READING DATA

# %%
print("Reading:", input_path)
df = pd.read_csv(input_path)
print("Rows, cols:", df.shape)
df.head()
# Out:
# Reading: c:\Users\SPEED LAP\OneDrive\Desktop\hotel_bookings FP MSA.csv
# Rows, cols: (119390, 32)
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# 1                        0                     0       2  ...    No Deposit
# 2                        0                     1       1  ...    No Deposit
# 3                        0                     1       1  ...    No Deposit
# 4                        0                     2       2  ...    No Deposit
#
#    agent company days_in_waiting_list customer_type   adr  \
# 0    NaN     NaN                    0     Transient   0.0
# 1    NaN     NaN                    0     Transient   0.0
# 2    NaN     NaN                    0     Transient  75.0
# 3  304.0     NaN                    0     Transient  75.0
# 4  240.0     NaN                    0     Transient  98.0
#
#    required_car_parking_spaces  total_of_special_requests  reservation_status  \
# 0                            0                          0           Check-Out
# 1                            0                          0           Check-Out
# 2                            0                          0           Check-Out
# 3                            0                          0           Check-Out
# 4                            0                          1           Check-Out
#
#   reservation_status_date
# 0                7/1/2015
# 1                7/1/2015
# 2                7/2/2015
# 3                7/2/2015
# 4                7/3/2015
#
# [5 rows x 32 columns]

# %% [markdown]
# # CLeaning

# %%
df['children'] = df['children'].fillna(0).round().astype(int)
df['babies'] = df['babies'].fillna(0).astype(int)

# %%
df['total_nights'] = df['stays_in_weekend_nights'] + df['stays_in_week_nights']

# %%
if 'reservation_status_date' in df.columns:
    df['reservation_status_date'] = pd.to_datetime(df['reservation_status_date'], dayfirst=False, errors='coerce')

# %%
df_before = len(df)
df = df.drop_duplicates()
print("Dropped duplicates:", df_before - len(df))
# Out:
# Dropped duplicates: 31994

# %%
df['adr'] = pd.to_numeric(df['adr'], errors='coerce')
median_adr = df.loc[df['adr'] > 0, 'adr'].median()
df.loc[df['adr'] <= 0, 'adr'] = median_adr
df['adr'] = df['adr'].fillna(median_adr)

print(f"ADR column cleaned. Median used: {median_adr}")
# Out:
# ADR column cleaned. Median used: 99.0

# %%
df.loc[(df['adults'] == 0) & (df['children'] + df['babies'] > 0), 'adults'] = 1

# %%
df['total_people'] = df.get('adults',0) + df.get('children',0) + df.get('babies',0)

# %%
for col in df.select_dtypes(include='object').columns:
    df[col] = df[col].astype(str).str.strip()

# %%
df['agent'] = df['agent'].fillna(0)
df['company'] = df['company'].fillna(0)

# %% [markdown]
# # SAVE FILE

# %%
df.to_csv(clean_csv_path, index=False)
print("Saved cleaned CSV to:", clean_csv_path)
# Out:
# Saved cleaned CSV to: c:\Users\SPEED LAP\OneDrive\Desktop\hotel_bookings_Cleaned.csv
